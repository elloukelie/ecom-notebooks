# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
tf.__version__
# Out:
# '2.19.0'

# %%
df = pd.read_csv('csvs/Churn_Modelling.csv')
df_copy = df.copy()
df_copy.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
X = df_copy.drop(['CustomerId', 'Surname', 'Exited'], axis =1)
y = df['Exited']

# %%
X = pd.get_dummies(X, columns=['Gender'], drop_first=True)
X = pd.get_dummies(X, columns=['Geography'], drop_first=True)
X.head()
# Out:
#    RowNumber  CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          1          619   42       2       0.00              1          1
# 1          2          608   41       1   83807.86              1          0
# 2          3          502   42       8  159660.80              3          1
# 3          4          699   39       1       0.00              2          0
# 4          5          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Gender_Male  Geography_Germany  \
# 0               1        101348.88        False              False
# 1               1        112542.58        False              False
# 2               0        113931.57        False              False
# 3               0         93826.63        False              False
# 4               1         79084.10        False              False
#
#    Geography_Spain
# 0            False
# 1             True
# 2            False
# 3            False
# ...

# %%
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size=0.3, random_state=42)
scaler = StandardScaler()

scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.fit_transform(X_test)

# %%
ann = tf.keras.models.Sequential()

ann.add(tf.keras.layers.Dense(units=10))

ann.add(tf.keras.layers.Dense(units=10, activation='relu'))

ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
ann.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %%
ann.fit(scaled_X_train, y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5702 - loss: 0.7070
# Epoch 2/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7973 - loss: 0.5001
# Epoch 3/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8062 - loss: 0.4646
# Epoch 4/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8092 - loss: 0.4517
# Epoch 5/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8126 - loss: 0.4394
# Epoch 6/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8101 - loss: 0.4365
# Epoch 7/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8225 - loss: 0.4232
# Epoch 8/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8152 - loss: 0.4280
# Epoch 9/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8190 - loss: 0.4197
# Epoch 10/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8163 - loss: 0.4269
# Epoch 11/100
# ...

# %%
y_pred = (ann.predict(scaled_X_test) > 0.5)

print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 0.867
# [[2327   89]
#  [ 310  274]]

# %%
new_customer_details = [[600, 40, 3, 60000, 2, 1, 1, 50000, 1, 1, 0, 0]]

scaled_new_customer_details = scaler.transform(new_customer_details)
ann.predict(scaled_new_customer_details) > 0.5
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# /home/elloukelie/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[False]])

# %% [markdown]
# End of slide 62 - ANN
